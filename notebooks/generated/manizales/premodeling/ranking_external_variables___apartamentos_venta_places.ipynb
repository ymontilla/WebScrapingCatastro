# %%
# %load_ext dotenv
# %reload_ext dotenv
# %dotenv

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
import sys
import os
from os.path import dirname

UTILS_PATH=os.environ.get('REPO') + "/notebooks/commons"
sys.path.append(dirname(UTILS_PATH))

from commons import check_args, gen_paths
from commons import coordinates_bounds, plot_feature_importances
from commons import check_args_variables, gen_paths_variables

# %%
def load_posts(source_path, clean_path):
    external = pd.read_parquet(source_path)
    external.loc[:, "lat"] = external["lat"].apply(float)
    external.loc[:, "lon"] = external["lon"].apply(float)
    
    fincaraiz = pd.read_parquet(clean_path)
    return external, fincaraiz

# %%
if __name__ == "__main__":
    source = "PLACES"
    city = "manizales"
    
    property_type = "apartamentos"
    post_type = "venta"
    
    base_path = os.environ.get('REPO')
    
    source_path = base_path + gen_paths_variables(source, city)
    raw_path, clean_path = gen_paths(city, property_type, post_type)
        
    raw_path = base_path + raw_path
    clean_path = base_path + clean_path

# %%
external_variables, fincaraiz = load_posts(source_path, clean_path)

# %%
from math import cos, asin, sqrt
def distance(lat1, lon1, lat2, lon2):
    """
    El resultado de la medición de distancia esta en kilometros.
    """
    p = 0.017453292519943295     #Pi/180
    a = 0.5 - cos((lat2 - lat1) * p)/2 + cos(lat1 * p) * cos(lat2 * p) * (1 - cos((lon2 - lon1) * p)) / 2
    return 12742 * asin(sqrt(a))

def post_to_place_distance(publications, places, index):
    publication = publications.loc[index]
    
    places_to_point = places.copy()
    places_to_point.loc[:, "fid"] = publication["fid"]
    
    places_to_point.loc[:, "latitide"] = publication["latitude"]
    places_to_point.loc[:, "longitude"] = publication["longitude"]
    
    places_to_point.loc[:, "distance"] = places_to_point.apply(
        lambda e: distance(publication["latitude"], publication["longitude"], e["lat"], e["lon"]), axis=1)
        
    return places_to_point

import functools
from multiprocessing import Pool
def get_near_points(external_variables, fincaraiz):    
    distance_map = functools.partial(
        post_to_place_distance, 
        fincaraiz, external_variables)
    
    pool = Pool(8)
    distances = pool.map(
        distance_map,
        fincaraiz.index
    )

    return pd.concat(distances).reset_index(drop=True)

# %%
distances_map = get_near_points(external_variables, fincaraiz)
distances_map.head()
# Out:
#         lat        lon     amenity  \
# 0  5.045668 -75.528992  university
# 1  5.045668 -75.528992  university
# 2  5.001526 -75.598802  university
# 3  4.985796 -75.606928  university
# 4  4.983539 -75.605624  university
#
#                                                 name      fid  latitide  \
# 0               Universidad Antonio Nariño Manizales  5478594     5.059
# 1                     UAN Universidad Antonio Nariño  5478594     5.059
# 2                                          Mànizales  5478594     5.059
# 3  CUN - Corporación Unificada Nacional de Educac...  5478594     5.059
# 4   JUZGADO PRIMERO PROMISCUO MUNICIPAL DE CHINCHINÁ  5478594     5.059
#
#    longitude   distance
# 0 -75.478996   5.732616
# 1 -75.478996   5.732616
# 2 -75.478996  14.729161
# 3 -75.478996  16.342258
# 4 -75.478996  16.344626

# %%
distances_map.loc[distances_map["distance"] == distances_map["distance"].min()]
# Out:
#               lat        lon        amenity  \
# 34060    5.070275 -75.513817     university
# 34061    5.070275 -75.513817     university
# 34090    5.070275 -75.513817  shopping_mall
# 34091    5.070275 -75.513817  shopping_mall
# 34092    5.070275 -75.513817  shopping_mall
# ...           ...        ...            ...
# 7686243  5.070275 -75.513817     restaurant
# 7686244  5.070275 -75.513817     restaurant
# 7686245  5.070275 -75.513817     restaurant
# 7686246  5.070275 -75.513817     restaurant
# 7686247  5.070275 -75.513817     restaurant
#
#                                                     name      fid  latitide  \
# 34060                        Yerly natalia López Acevedo  4669095  5.070275
# 34061             Colegio de Jueces y Fiscales de Caldas  4669095  5.070275
# 34090                       Auditorio unicentro estrella  4669095  5.070275
# 34091                                     El cable plaza  4669095  5.070275
# 34092                                      Ley sancancio  4669095  5.070275
# ...                                                  ...      ...       ...
# 7686243  CLUB: NUTRICION ,SALUD, BIENESTAR, TERMOMASAJES  4668763  5.070275
# 7686244                               Algussto Manizales  4668763  5.070275
# 7686245                         villa pilar hamburguesas  4668763  5.070275
# 7686246                              Restaurantes chinos  4668763  5.070275
# 7686247                              Jalapeños Al Carbon  4668763  5.070275
#
#          longitude  distance
# 34060   -75.513817       0.0
# 34061   -75.513817       0.0
# 34090   -75.513817       0.0
# 34091   -75.513817       0.0
# 34092   -75.513817       0.0
# ...            ...       ...
# 7686243 -75.513817       0.0
# 7686244 -75.513817       0.0
# 7686245 -75.513817       0.0
# 7686246 -75.513817       0.0
# 7686247 -75.513817       0.0
#
# [2532 rows x 8 columns]

# %%
## Un punto de interes es cercano a la publicicación cuando esta a menos de 3 kilometros

near_points = distances_map.loc[distances_map["distance"] < 3]
near_points.head()
# Out:
#           lat        lon                  amenity                  name  \
# 105  5.040884 -75.498227         secondary_school  Liceo Mixto Aranjuez
# 117  5.042459 -75.499351                   police          CAI Aranjuez
# 156  5.053020 -75.505044                     park    Camilo Torres Park
# 158  5.050831 -75.503086                     park    Jose Restrepo Park
# 202  5.056053 -75.504015  local_government_office     Cootransnorcaldas
#
#          fid  latitide  longitude  distance
# 105  5478594     5.059 -75.478996  2.931712
# 117  5478594     5.059 -75.478996  2.909693
# 156  5478594     5.059 -75.478996  2.960751
# 158  5478594     5.059 -75.478996  2.818577
# 202  5478594     5.059 -75.478996  2.790444

# %%
near_points.describe()
# Out:
#                 lat           lon      latitide     longitude      distance
# count  3.861038e+06  3.861038e+06  3.861038e+06  3.861038e+06  3.861038e+06
# mean   5.060535e+00 -7.550020e+01  5.059561e+00 -7.549920e+01  1.678848e+00
# std    1.018048e-02  1.531901e-02  9.911940e-03  1.544290e-02  7.869402e-01
# min    5.006504e+00 -7.556671e+01  5.027696e+00 -7.554888e+01  0.000000e+00
# 25%    5.053965e+00 -7.551366e+01  5.051657e+00 -7.551139e+01  1.044330e+00
# 50%    5.062292e+00 -7.549911e+01  5.060166e+00 -7.549689e+01  1.699011e+00
# 75%    5.067488e+00 -7.548843e+01  5.066400e+00 -7.548704e+01  2.359246e+00
# max    5.116710e+00 -7.542547e+01  5.097740e+00 -7.544824e+01  3.000000e+00

# %%
near_points_by_categories = near_points[["fid", "amenity", "name"]].groupby(["fid", "amenity"]).count()
near_points_by_categories.head()
# Out:
#                         name
# fid     amenity
# 1995924 amusement_park     1
#         bank             107
#         church            63
#         hospital          57
#         library           12

# %%
index = list(zip(*near_points_by_categories.index))
near_points_by_categories.loc[:, "fid"] = index[0]
near_points_by_categories.loc[:, "amenity"] = index[1]
near_points_by_categories.loc[:, "count"] = near_points_by_categories["name"]

near_points_by_categories = near_points_by_categories.reset_index(drop=True)
near_points_by_categories = near_points_by_categories.drop(["name"], axis=1)
near_points_by_categories.head()
# Out:
#        fid         amenity  count
# 0  1995924  amusement_park      1
# 1  1995924            bank    107
# 2  1995924          church     63
# 3  1995924        hospital     57
# 4  1995924         library     12

# %%
posts_full = fincaraiz[["fid"]].copy()
posts_full = posts_full.drop_duplicates(["fid"])

def safe_get(post, amenity):
    client = near_points_by_categories.loc[
        near_points_by_categories["fid"] == post["fid"]]
    
    if client.shape[0] == 0:
        return 0
    
    client = client.loc[client["amenity"] == amenity]
    if client.shape[0] == 0:
        return 0
    
    return client["count"].iloc[0]

# %%
for amenity in external_variables["amenity"].value_counts().index:
    posts_full.loc[:, amenity] = posts_full.apply(lambda e: safe_get(e, amenity), axis=1)

# %%
posts_full["airport"].describe()
# Out:
# count    3004.000000
# mean        0.181092
# std         0.385158
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: airport, dtype: float64

# %%
## Las features y las etiquetas son las mismas en todos los métodos

FEATURES = list(filter(lambda e: e != "fid", posts_full.columns))
LABEL = "price"

final_features = pd.merge(posts_full, fincaraiz[["fid", "price"]], on="fid")

X = final_features[FEATURES].values
y = final_features[LABEL].values

# %% [markdown]
# ## Selección de features univariada

# %%
selector = SelectKBest(f_regression, k=5)
X_new = selector.fit_transform(X, y)
X_new.shape
# Out:
# (3004, 5)

# %%
feature_importances = pd.DataFrame({'importance': selector.scores_, 'feature': FEATURES})

# %%
plot_feature_importances(feature_importances)
# Out:
# 9 features required for 0.90 of cumulative importance
#     index  importance                  feature  importance_normalized  \
# 0       7  115.872801               university               0.172535
# 1      11  104.798500                  library               0.156045
# 2       5   82.258331            shopping_mall               0.122483
# 3       6   80.750069                 hospital               0.120237
# 4       8   71.690350  local_government_office               0.106747
# 5      12   58.866598           amusement_park               0.087653
# 6      13   43.063101                  airport               0.064121
# 7       2   25.071227                     bank               0.037331
# 8      10   24.874457         secondary_school               0.037038
# 9       3   24.480618                   church               0.036452
# 10      0   22.300623               restaurant               0.033206
# 11      4    8.628684                     park               0.012848
# 12      1    8.524407                   school               0.012693
# 13      9    0.409654                   police               0.000610
#
#     cumulative_importance
# 0                0.172535
# 1                0.328581
# 2                0.451064
# 3                0.571301
# 4                0.678048
# 5                0.765701
# 6                0.829822
# 7                0.867153
# 8                0.904191
# 9                0.940643
# 10               0.973849
# 11               0.986697
# 12               0.999390
# 13               1.000000

# %% [markdown]
# ## Eliminación recursiva de features

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
reg = LinearRegression().fit(X, y)
reg.score(X, y)
# Out:
# 0.11110533953944213

# %%
rfe = RFE(estimator=reg, n_features_to_select=1, step=1)
rfe.fit(X, y)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=1)

# %%
feature_importances = pd.DataFrame({'importance': rfe.ranking_, 'feature': FEATURES})

# %%
plot_feature_importances(feature_importances)
# Out:
# 10 features required for 0.90 of cumulative importance
#     index  importance                  feature  importance_normalized  \
# 0       8          14  local_government_office               0.133333
# 1       4          13                     park               0.123810
# 2       1          12                   school               0.114286
# 3       3          11                   church               0.104762
# 4       0          10               restaurant               0.095238
# 5       2           9                     bank               0.085714
# 6       6           8                 hospital               0.076190
# 7       5           7            shopping_mall               0.066667
# 8      11           6                  library               0.057143
# 9       7           5               university               0.047619
# 10     12           4           amusement_park               0.038095
# 11      9           3                   police               0.028571
# 12     10           2         secondary_school               0.019048
# 13     13           1                  airport               0.009524
#
#     cumulative_importance
# 0                0.133333
# 1                0.257143
# 2                0.371429
# 3                0.476190
# 4                0.571429
# 5                0.657143
# 6                0.733333
# 7                0.800000
# 8                0.857143
# 9                0.904762
# 10               0.942857
# 11               0.971429
# 12               0.990476
# 13               1.000000

# %% [markdown]
# ## Selección de features basada en arboles

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
forest = ExtraTreesRegressor(n_estimators=100, random_state=0)
forest.fit(X, y)
# Out:
# ExtraTreesRegressor(random_state=0)

# %%
feature_importances = pd.DataFrame({'importance':  forest.feature_importances_, 'feature': FEATURES})

# %%
plot_feature_importances(feature_importances)
# Out:
# 11 features required for 0.90 of cumulative importance
#     index  importance                  feature  importance_normalized  \
# 0       0    0.126943               restaurant               0.126943
# 1       7    0.116318               university               0.116318
# 2       3    0.112178                   church               0.112178
# 3       4    0.104071                     park               0.104071
# 4       1    0.081195                   school               0.081195
# 5      10    0.075800         secondary_school               0.075800
# 6       2    0.074409                     bank               0.074409
# 7       5    0.065809            shopping_mall               0.065809
# 8       6    0.065758                 hospital               0.065758
# 9       8    0.056174  local_government_office               0.056174
# 10      9    0.053894                   police               0.053894
# 11     11    0.035960                  library               0.035960
# 12     13    0.017602                  airport               0.017602
# 13     12    0.013890           amusement_park               0.013890
#
#     cumulative_importance
# 0                0.126943
# 1                0.243261
# 2                0.355439
# 3                0.459510
# 4                0.540706
# 5                0.616505
# 6                0.690915
# 7                0.756723
# 8                0.822481
# 9                0.878654
# 10               0.932548
# 11               0.968508
# 12               0.986110
# 13               1.000000
